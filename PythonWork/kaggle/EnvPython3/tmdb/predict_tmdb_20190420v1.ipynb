# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %%
train_data = pd.read_csv('../input/train.csv')
test_data = pd.read_csv('../input/test.csv')
print (train_data.head())
print (train_data.columns)
print (test_data.columns)
# Out:
#    id    ...      revenue
# 0   1    ...     12314651
# 1   2    ...     95149435
# 2   3    ...     13092000
# 3   4    ...     16000000
# 4   5    ...      3923970
#
# [5 rows x 23 columns]
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew'],
#       dtype='object')

# %%
print (train_data.shape)
print (train_data.info())
# Out:
# (3000, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
# id                       3000 non-null int64
# belongs_to_collection    604 non-null object
# budget                   3000 non-null int64
# genres                   2993 non-null object
# homepage                 946 non-null object
# imdb_id                  3000 non-null object
# original_language        3000 non-null object
# original_title           3000 non-null object
# overview                 2992 non-null object
# popularity               3000 non-null float64
# poster_path              2999 non-null object
# production_companies     2844 non-null object
# production_countries     2945 non-null object
# release_date             3000 non-null object
# runtime                  2998 non-null float64
# spoken_languages         2980 non-null object
# status                   3000 non-null object
# tagline                  2403 non-null object
# title                    3000 non-null object
# Keywords                 2724 non-null object
# cast                     2987 non-null object
# crew                     2984 non-null object
# revenue                  3000 non-null int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.1+ KB
# None

# %%
print (train_data.describe())
# Out:
#                 id        budget      ...           runtime       revenue
# count  3000.000000  3.000000e+03      ...       2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07      ...        107.856571  6.672585e+07
# std     866.169729  3.702609e+07      ...         22.086434  1.375323e+08
# min       1.000000  0.000000e+00      ...          0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00      ...         94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06      ...        104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07      ...        118.000000  6.891920e+07
# max    3000.000000  3.800000e+08      ...        338.000000  1.519558e+09
#
# [8 rows x 5 columns]

# %%
print (train_data.isnull().sum())
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
print (test_data.isnull().sum())
# Out:
# id                          0
# belongs_to_collection    3521
# budget                      0
# genres                     16
# homepage                 2978
# imdb_id                     0
# original_language           0
# original_title              0
# overview                   14
# popularity                  0
# poster_path                 1
# production_companies      258
# production_countries      102
# release_date                1
# runtime                     4
# spoken_languages           42
# status                      2
# tagline                   863
# title                       3
# Keywords                  393
# cast                       13
# crew                       22
# dtype: int64

# %%
# print (train_data.status.unique())
# print (  train_data[train_data.status.isin(['Released', 'Rumored'])] )
# print (len(train_data['homepage'].unique().tolist()))

# print (len(train_data.tagline.unique().tolist()))
# print (train_data['title'].unique())

# %%
drop_features = ['belongs_to_collection', 'homepage', 'tagline', 'production_companies',
                 'production_countries', 'Keywords', 'imdb_id', 'status','cast','crew', 'poster_path',
                'overview', 'release_date']
train_data = train_data.drop(drop_features, axis=1)
print (train_data.isnull().sum())
# Out:
# id                    0
# budget                0
# genres                7
# original_language     0
# original_title        0
# popularity            0
# runtime               2
# spoken_languages     20
# title                 0
# revenue               0
# dtype: int64

# %%
# print (train_data.genres.head())
# train_data['genres_mean_coding'] = train_data.groupby('genres')['revenue'].transform('mean')
# print (train_data.groupby('genres')['revenue'].transform('mean'))
# train_data.drop('genres', axis=1)
# print (train_data.columns)

# %%
# print (train_data.runtime.unique())
# print (train_data.Keywords.unique())
# print (len(train_data.production_companies.unique().tolist()))
print (train_data.shape)
train_data = train_data[pd.notnull(train_data['spoken_languages'])]
# train_data = train_data[pd.notnull(train_data['crew'])]
# train_data = train_data[pd.notnull(train_data['overview'])]
train_data = train_data[pd.notnull(train_data['genres'])]
train_data = train_data[pd.notnull(train_data['runtime'])]

print (train_data.shape)
print (train_data.isnull().sum())
# Out:
# (3000, 10)
# (2975, 10)
# id                   0
# budget               0
# genres               0
# original_language    0
# original_title       0
# popularity           0
# runtime              0
# spoken_languages     0
# title                0
# revenue              0
# dtype: int64

# %%
test_data = test_data.drop(drop_features, axis=1)
print (test_data.isnull().sum())
# Out:
# id                    0
# budget                0
# genres               16
# original_language     0
# original_title        0
# popularity            0
# runtime               4
# spoken_languages     42
# title                 3
# dtype: int64

# %%
# print (test_data.genres.head())
# test_data['genres_mean_coding'] = test_data.groupby('genres')['revenue'].transform('mean')
# print (test_data.groupby('genres')['revenue'].transform('mean'))
# test_data.drop('genres', axis=1)

# %%
# print (test_data.shape)
# print (test_data.spoken_languages.value_counts())
# test_data = test_data[pd.notnull(test_data['spoken_languages'])]
# # test_data = test_data[pd.notnull(test_data['crew'])]
# # test_data = test_data[pd.notnull(test_data['overview'])]
# test_data = test_data[pd.notnull(test_data['genres'])]
# test_data = test_data[pd.notnull(test_data['runtime'])]
test_data['spoken_languages'] = test_data['spoken_languages'].fillna('English')
test_data['genres'] = test_data['genres'].fillna('Drama')
test_data['runtime'] = test_data['runtime'].fillna(100.0)
test_data['title'] = test_data['title'].fillna('A Nightmare on Elm Street')

print (test_data.title.value_counts())

# print (test_data.shape)
# print (test_data.isnull().sum())
# Out:
# A Nightmare on Elm Street                5
# Beowulf                                  2
# Joe                                      2
# The Rookie                               2
# Party Girl                               2
# The Omen                                 2
# Three                                    2
# Halloween II                             2
# The In-Laws                              2
# Alive                                    2
# Conan the Barbarian                      2
# The Wave                                 2
# The Girl with the Dragon Tattoo          2
# True Grit                                2
# No Escape                                2
# Planet of the Apes                       2
# Earth                                    2
# Prom Night                               2
# Gloria                                   2
# Night of the Living Dead                 2
# Footloose                                2
# Ghostbusters                             2
# Taxi                                     2
# Great Expectations                       2
# Carrie                                   2
# Pinocchio                                2
# Endless Love                             2
# The In Crowd                             2
# Julia                                    2
# Wanted                                   2
#                                         ..
# Finding Vivian Maier                     1
# Tightrope                                1
# Das Boot                                 1
# Death Note: The Last Name                1
# Company                                  1
# Central Intelligence                     1
# Austin Powers: The Spy Who Shagged Me    1
# Maniac                                   1
# Ticket to Vegas                          1
# F/X                                      1
# Babylon A.D.                             1
# Parrish                                  1
# P.S. I Love You                          1
# Sunshine Superman                        1
# 976-EVIL                                 1
# American Gangster                        1
# Bullitt                                  1
# Sex Tape                                 1
# How to Lose a Guy in 10 Days             1
# Mechanic: Resurrection                   1
# The Emperor's New Groove                 1
# Bride Wars                               1
# At Close Range                           1
# On Golden Pond                           1
# Special ID                               1
# Seven Samurai                            1
# Before the Rain                          1
# Gorky Park                               1
# Dilwale Dulhania Le Jayenge              1
# Limbo                                    1
# Name: title, Length: 4342, dtype: int64

# %%
print (len(train_data.spoken_languages.unique().tolist()))
print (train_data.info())
print (len(train_data.genres.unique().tolist()))
# Out:
# 401
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2975 entries, 0 to 2999
# Data columns (total 10 columns):
# id                   2975 non-null int64
# budget               2975 non-null int64
# genres               2975 non-null object
# original_language    2975 non-null object
# original_title       2975 non-null object
# popularity           2975 non-null float64
# runtime              2975 non-null float64
# spoken_languages     2975 non-null object
# title                2975 non-null object
# revenue              2975 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 255.7+ KB
# None
# 869

# %%
# from sklearn.preprocessing import OneHotEncoder
# print (train_data.isnull().sum())

# onehot_encoder = OneHotEncoder()
# train_data.genres = onehot_encoder.fit_transform(train_data.genres)

# train_data.original_language = onehot_encoder.fit_transform(train_data.original_language)
# train_data.spoken_languages = onehot_encoder.fit_transform(train_data.spoken_languages)
# train_data.original_title = onehot_encoder.fit_transform(train_data.original_title)
# train_data.title = onehot_encoder.fit_transform(train_data.title)
# print (train_data.genres.head())

# %%
from sklearn.preprocessing import LabelEncoder
print (train_data.isnull().sum())
label_encoder = LabelEncoder()
train_data.genres = label_encoder.fit_transform(train_data.genres)
train_data.original_language = label_encoder.fit_transform(train_data.original_language)
train_data.spoken_languages = label_encoder.fit_transform(train_data.spoken_languages)
train_data.original_title = label_encoder.fit_transform(train_data.original_title)
train_data.title = label_encoder.fit_transform(train_data.title)
print (train_data.genres.head())
# Out:
# id                   0
# budget               0
# genres               0
# original_language    0
# original_title       0
# popularity           0
# runtime              0
# spoken_languages     0
# title                0
# revenue              0
# dtype: int64
# 0    693
# 1    643
# 2    390
# 3    730
# 4    588
# Name: genres, dtype: int64

# %%
print (train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2975 entries, 0 to 2999
# Data columns (total 10 columns):
# id                   2975 non-null int64
# budget               2975 non-null int64
# genres               2975 non-null int64
# original_language    2975 non-null int64
# original_title       2975 non-null int64
# popularity           2975 non-null float64
# runtime              2975 non-null float64
# spoken_languages     2975 non-null int64
# title                2975 non-null int64
# revenue              2975 non-null int64
# dtypes: float64(2), int64(8)
# memory usage: 255.7 KB
# None

# %%
print (test_data.isnull().sum())

test_data.genres = label_encoder.fit_transform(test_data.genres)
test_data.original_language = label_encoder.fit_transform(test_data.original_language)
test_data.spoken_languages = label_encoder.fit_transform(test_data.spoken_languages)
test_data.original_title = label_encoder.fit_transform(test_data.original_title)
test_data.title = label_encoder.fit_transform(test_data.title)
print (test_data.genres.head())
# Out:
# id                   0
# budget               0
# genres               0
# original_language    0
# original_title       0
# popularity           0
# runtime              0
# spoken_languages     0
# title                0
# dtype: int64
# 0    144
# 1    555
# 2    786
# 3    387
# 4    898
# Name: genres, dtype: int64

# %%
print (train_data.isnull().sum())
# Out:
# id                   0
# budget               0
# genres               0
# original_language    0
# original_title       0
# popularity           0
# runtime              0
# spoken_languages     0
# title                0
# revenue              0
# dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
y = train_data['revenue']
X = train_data.drop('revenue', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
validate_predicted_rf = rf.predict(X_test)
# print (predicted)
print (mean_squared_error(y_test, validate_predicted_rf))
# Out:
# 7372114056332328.0
# /opt/conda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=42)
xgb_model.fit(X_train, y_train)
validate_predicted_xgb = xgb_model.predict(X_test)
# print (predicted)
print (mean_squared_error(y_test, validate_predicted_xgb))
# Out:
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 6862424147477752.0

# %%
X_val_level2 = np.c_[validate_predicted_rf, validate_predicted_xgb]
print (X_val_level2[:10])
print (len(X_val_level2[0]))
print (y_train.shape)
# Out:
# [[2.63478310e+06 6.89024800e+06]
#  [1.44987275e+07 3.33106580e+07]
#  [3.67861997e+07 2.35022020e+07]
#  [7.87549438e+07 6.72580240e+07]
#  [6.47918756e+07 1.10776700e+07]
#  [7.11277532e+07 5.23089720e+07]
#  [2.58060825e+08 2.19998784e+08]
#  [1.64443905e+07 1.53361340e+07]
#  [4.24834392e+07 3.09517780e+07]
#  [1.14889842e+08 1.16994584e+08]]
# 2
# (2082,)

# %%
print (test_data.head())
# Out:
#      id   budget  genres  ...    runtime  spoken_languages  title
# 0  3001        0     144  ...       90.0               294   2523
# 1  3002    88000     555  ...       65.0               353    317
# 2  3003        0     786  ...      100.0               353    164
# 3  3004  6800000     387  ...      130.0               370   1666
# 4  3005  2000000     898  ...       92.0               353   1678
#
# [5 rows x 9 columns]

# %%
test_predicted_rf = rf.predict(test_data)
print (test_predicted_rf)
# Out:
# [2.65392380e+07 5.80745270e+06 3.10684296e+07 ... 1.25796626e+08
#  1.06961604e+08 7.70942156e+07]

# %%
test_predicted_xgb = xgb_model.predict(test_data)
print (test_predicted_xgb)
# Out:
# [-1.1617171e+06 -2.1713775e+06 -9.5803125e+03 ...  9.5093072e+07
#   6.8913040e+07  5.5524860e+07]

# %%
X_test_level2 = np.c_[test_predicted_rf, test_predicted_xgb]
print (X_test_level2[:10])
# Out:
# [[ 2.65392380e+07 -1.16171712e+06]
#  [ 5.80745270e+06 -2.17137750e+06]
#  [ 3.10684296e+07 -9.58031250e+03]
#  [ 7.03403074e+07  4.60986640e+07]
#  [ 2.71188010e+06 -9.22831062e+05]
#  [ 1.49998713e+07  5.40572300e+06]
#  [ 2.41669474e+07  3.28453740e+07]
#  [ 9.54476413e+07  7.63190480e+07]
#  [ 7.93116944e+07  2.25853020e+07]
#  [ 3.42170728e+08  2.70656992e+08]]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_val_level2, y_test)
validate_predicted_lr = lr.predict(X_test_level2)
print (len(validate_predicted_lr))

# print (mean_squared_error(y_test, validate_predicted_lr))
# Out:
# 4398

# %%
submission = pd.DataFrame()
submission['id'] = test_data['id']
submission['revenue'] = validate_predicted_lr

print (submission.head())
submission.to_csv('submission_v3.csv', index=False)
# Out:
#      id       revenue
# 0  3001  1.117542e+07
# 1  3002  5.493630e+06
# 2  3003  1.302282e+07
# 3  3004  5.254191e+07
# 4  3005  5.555719e+06
